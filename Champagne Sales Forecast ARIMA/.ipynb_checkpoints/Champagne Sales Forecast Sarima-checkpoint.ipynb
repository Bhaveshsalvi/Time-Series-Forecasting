# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.stattools import adfuller, kpss

# %%
df = pd.read_csv("perrin-freres-monthly-champagne-.csv")

# %%
df.tail(10)
# Out:
#          Month    Sales
# 95  1971-12-01  12670.0
# 96  1972-01-01   4348.0
# 97  1972-02-01   3564.0
# 98  1972-03-01   4577.0
# 99  1972-04-01   4788.0
# 100 1972-05-01   4618.0
# 101 1972-06-01   5312.0
# 102 1972-07-01   4298.0
# 103 1972-08-01   1413.0
# 104 1972-09-01   5877.0

# %%
pd.set_option('display.max_rows',1000)

# %%
df.dropna(inplace=True)

# %%
df.rename(columns={'Perrin Freres monthly champagne sales millions ?64-?72':'Sales'},inplace = True)

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
df.dtypes
# Out:
# Month    datetime64[ns]
# Sales           float64
# dtype: object

# %%
df.head(5)
# Out:
#        Month   Sales
# 0 1964-01-01  2815.0
# 1 1964-02-01  2672.0
# 2 1964-03-01  2755.0
# 3 1964-04-01  2721.0
# 4 1964-05-01  2946.0

# %%
df.set_index('Month', inplace=True)

# %%
plt.plot(df)

# %%
sm.qqplot(df)
plt.show()
#sm.qqplot(np.random.randn(1000))

# %%
results = seasonal_decompose(df,model='additive')
print(results.trend)
print(results.seasonal)
print(results.resid)
print(results.observed)
# Out:
# Month
# 1964-01-01   NaN
# 1964-02-01   NaN
# 1964-03-01   NaN
# 1964-04-01   NaN
# 1964-05-01   NaN
#               ..
# 1972-05-01   NaN
# 1972-06-01   NaN
# 1972-07-01   NaN
# 1972-08-01   NaN
# 1972-09-01   NaN
# Name: trend, Length: 105, dtype: float64
# Month
# 1964-01-01   -1223.411582
# 1964-02-01   -1624.250124
# 1964-03-01    -979.229291
# 1964-04-01    -850.244916
# 1964-05-01    -652.096106
#                  ...
# 1972-05-01    -652.096106
# 1972-06-01    -671.173487
# 1972-07-01   -1242.500124
# 1972-08-01   -3060.505332
# 1972-09-01    -312.390749
# Name: seasonal, Length: 105, dtype: float64
# Month
# 1964-01-01   NaN
# 1964-02-01   NaN
# 1964-03-01   NaN
# 1964-04-01   NaN
# 1964-05-01   NaN
#               ..
# 1972-05-01   NaN
# 1972-06-01   NaN
# 1972-07-01   NaN
# 1972-08-01   NaN
# 1972-09-01   NaN
# Name: resid, Length: 105, dtype: float64
# Month
# 1964-01-01    2815.0
# 1964-02-01    2672.0
# 1964-03-01    2755.0
# 1964-04-01    2721.0
# 1964-05-01    2946.0
#                ...
# 1972-05-01    4618.0
# 1972-06-01    5312.0
# 1972-07-01    4298.0
# 1972-08-01    1413.0
# 1972-09-01    5877.0
# Length: 105, dtype: float64

# %%
df_reconstructed = pd.concat([results.seasonal,results.trend,results.resid,results.observed],axis=1)
df_reconstructed.columns = ['seas','trend','resid','actual_values']

# %%
df_reconstructed
# Out:
#                    seas        trend        resid  actual_values
# Month
# 1971-07-01 -1242.500124  5657.833333   217.666791         4633.0
# 1971-08-01 -3060.505332  5691.833333  -972.328001         1659.0
# 1971-09-01  -312.390749  5720.708333   542.682416         5951.0
# 1971-10-01   965.729043  5737.500000   277.770957         6981.0
# 1971-11-01  3730.130084  5725.833333   395.036582         9851.0
# 1971-12-01  5919.942584  5727.750000  1022.307416        12670.0
# 1972-01-01 -1223.411582  5732.041667  -160.630084         4348.0
# 1972-02-01 -1624.250124  5707.833333  -519.583209         3564.0
# 1972-03-01  -979.229291  5694.500000  -138.270709         4577.0
# 1972-04-01  -850.244916          NaN          NaN         4788.0
# 1972-05-01  -652.096106          NaN          NaN         4618.0
# 1972-06-01  -671.173487          NaN          NaN         5312.0
# 1972-07-01 -1242.500124          NaN          NaN         4298.0
# 1972-08-01 -3060.505332          NaN          NaN         1413.0
# 1972-09-01  -312.390749          NaN          NaN         5877.0

# %%
results.plot()
plt.show()

# %%
plt.plot(df_reconstructed['resid'])

# %%
sm.qqplot(df_reconstructed['resid'])
plt.show()

# %%
plot_acf(df_reconstructed['resid'])
plt.show()

# %%
#ADF Test

def adfuller_test(data):
    results = adfuller(data)
    labels = ['ADF test statistics', 'p-value','#Lags used','Num of obs used']
    #ADF test statistics, p-value,Lags used,Num of obs used = results
    for value , label in zip(results,labels):
        print(label +" : "+ str(value))
    if results[1] < 0.05:
        print("Rejecting the null hypothesis as Data is strong stationary")
    else:
        print("Failed to Reject the null hypothesis as Data is Weak stationary")

# %%
#KPSS Test

def kpss_test(data):
    results = kpss(data)
    labels = ['kpss test statistics', 'p-value','#Lags used','Num of obs used']
    #ADF test statistics, p-value,Lags used,Num of obs used = results
    for value , label in zip(results,labels):
        print(label +" : "+ str(value))
    if results[1] < 0.05:
        print("Failed to Reject the null hypothesis as Data is Weak stationary")
    else:
        print("Rejecting the null hypothesis as Data is strong stationary")

# %%
adfuller_test(df['Sales'])
# Out:
# ADF test statistics : -1.8335930563276237
# p-value : 0.3639157716602447
# #Lags used : 11
# Num of obs used : 93
# Failed to Reject the null hypothesis as Data is Weak stationary

# %%
kpss_test(df['Sales'])
# Out:
# kpss test statistics : 0.6091402884961419
# p-value : 0.021805428318532553
# #Lags used : 13
# Num of obs used : {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# Failed to Reject the null hypothesis as Data is Weak stationary
# C:\Users\Bhavesh\Miniconda3\lib\site-packages\statsmodels\tsa\stattools.py:1661: FutureWarning: The behavior of using lags=None will change in the next release. Currently lags=None is the same as lags='legacy', and so a sample-size lag length is used. After the next release, the default will change to be the same as lags='auto' which uses an automatic lag length selection method. To silence this warning, either use 'auto' or 'legacy'
#   warn(msg, FutureWarning)

# %% [markdown]
# ### Since data is not stationary we need to make it stationary by removing trend and seasonality

# %%
df['Sales first diff'] = df['Sales'].shift(1)

# %%
#df['Sales first diff'] = df['Sales first diff'].fillna('2815')

# %%
df['Sales first diff'] = df['Sales'] - df['Sales first diff']

# %%
df['Sales seasonal diff'] = df['Sales'].shift(12)

# %%
df['Sales seasonal diff'] = df['Sales'] - df['Sales seasonal diff']
